# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,RandomizedSearchCV,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
DF=pd.read_csv("car-sales-extended.csv")
DF.head()
DF.isnull().sum()
DF.plot()
# Out:
# <Axes: >

# %%
#DF.corr() 
pd.crosstab(DF["Colour"],DF["Price"]).plot (kind="hist",figsize=(3,3))
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.title("graph")
plt.show()

# %%
#encode
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
encode = OneHotEncoder()
column = ["Make","Colour"] 
Transformer=ColumnTransformer ([
    ("encode",encode,column)
    ])
y = DF["Price"]
X = DF.drop("Price", axis = 1)
X = Transformer.fit_transform(X)
print(X)
# Out:
#   (0, 1)	1.0
#   (0, 8)	1.0
#   (1, 0)	1.0
#   (1, 5)	1.0
#   (2, 1)	1.0
#   (2, 8)	1.0
#   (3, 3)	1.0
#   (3, 8)	1.0
#   (4, 2)	1.0
#   (4, 5)	1.0
#   (5, 1)	1.0
#   (5, 7)	1.0
#   (6, 3)	1.0
#   (6, 5)	1.0
#   (7, 1)	1.0
#   (7, 8)	1.0
#   (8, 2)	1.0
#   (8, 8)	1.0
#   (9, 1)	1.0
#   (9, 5)	1.0
#   (10, 2)	1.0
#   (10, 8)	1.0
#   (11, 2)	1.0
#   (11, 6)	1.0
#   (12, 2)	1.0
#   :	:
#   (987, 8)	1.0
#   (988, 2)	1.0
#   (988, 4)	1.0
#   (989, 3)	1.0
#   (989, 7)	1.0
#   (990, 3)	1.0
#   (990, 8)	1.0
#   (991, 1)	1.0
#   (991, 5)	1.0
#   (992, 1)	1.0
#   (992, 6)	1.0
#   (993, 2)	1.0
#   (993, 4)	1.0
#   (994, 0)	1.0
#   (994, 5)	1.0
#   (995, 3)	1.0
#   (995, 4)	1.0
#   (996, 2)	1.0
#   (996, 8)	1.0
#   (997, 2)	1.0
#   (997, 5)	1.0
#   (998, 1)	1.0
#   (998, 8)	1.0
#   (999, 3)	1.0
#   (999, 5)	1.0

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y, test_size= 0.2)
model = LinearRegression()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.15978904371416103

# %%
parameter={"C":np.logspace(1,7,11)}
model=RandomizedSearchCV(LogisticRegression(),param_distributions=parameter,cv=3)
model.fit(X_train,y_train)
model.score(X_test,y_test)
score=model.score(X_test,y_test)
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 parameter={"C":np.logspace(1,7,11)}
# ----> 2 model=RandomizedSearchCV(LogisticRegression(),param_distributions=parameter,cv=3)
#       3 model.fit(X_train,y_train)
#       4 model.score(X_test,y_test)
#
# NameError: name 'LogisticRegression' is not defined

# %%
parameter={"C":np.logspace(1,7,11) }
m2=GridSearchCV(LogisticRegression(),param_grid=parameter,cv=3)
m2.fit(X_train, y_train)
m2.score(X_test, y_test)
score= m2.score(X_train,y_train)
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 parameter={"C":np.logspace(1,7,11) }
# ----> 2 m2=GridSearchCV(LogisticRegression(),param_grid=parameter,cv=3)
#       3 m2.fit(X_train, y_train)
#       4 m2.score(X_test, y_test)
#
# NameError: name 'LogisticRegression' is not defined
